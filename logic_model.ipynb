# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/kesavsabari/Downloads/ANUVAAD_INDB_DiseaseTagged.xlsx")

# %%
df.head()
# Out:
#   food_code                                        food_name primarysource  \
# 0      A001       Amaranth seed, black (Amaranthus cruentus)      ifct2017
# 1      A002  Amaranth seed, pale brown (Amaranthus cruentus)      ifct2017
# 2      A003                    Bajra (Pennisetum typhoideum)      ifct2017
# 3      A004                         Barley (Hordeum vulgare)      ifct2017
# 4      A005                          Jowar (Sorghum vulgare)      ifct2017
#
#   secondarysource       food_group_nin  energy_kj  energy_kcal  carb_g  \
# 0             NaN  Cereals and millets     1490.0      356.110   59.98
# 1             NaN  Cereals and millets     1489.0      355.871   61.46
# 2             NaN  Cereals and millets     1456.0      347.984   61.78
# 3           ukfct  Cereals and millets     1321.0      315.719   61.29
# 4             NaN  Cereals and millets     1398.0      334.122   67.68
#
#    protein_g  fat_g  ...  unit_serving_vitb2_mg  unit_serving_vitb3_mg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2119 entries, 0 to 2118
# Data columns (total 86 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   food_code                    2109 non-null   object
#  1   food_name                    2109 non-null   object
#  2   primarysource                2109 non-null   object
#  3   secondarysource              195 non-null    object
#  4   food_group_nin               897 non-null    object
#  5   energy_kj                    2109 non-null   float64
#  6   energy_kcal                  2109 non-null   float64
#  7   carb_g                       2109 non-null   float64
#  8   protein_g                    2109 non-null   float64
#  9   fat_g                        2109 non-null   float64
#  10  freesugar_g                  2109 non-null   float64
#  11  fibre_g                      2109 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# food_code                        10
# food_name                        10
# primarysource                    10
# secondarysource                1924
# food_group_nin                 1222
#                                ...
# unit_serving_vitb9_ug          1187
# unit_serving_vitc_mg           1187
# unit_serving_carotenoids_ug    1187
# Notes                          2110
# Diseases_to_Avoid                 0
# Length: 86, dtype: int64
